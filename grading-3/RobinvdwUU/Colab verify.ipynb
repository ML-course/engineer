# %%
# Fill in your name using the format below and student ID number
your_name = "van de Water, Robin"
student_id = "1503618"
# !pip install --quiet openml 
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU') # Check whether GPUs are available
# %matplotlib inline
import openml as oml
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from google.colab import drive
drive.mount('/content/drive')
base_dir = '/content/drive/My Drive/assignment-3-RobinvdwUU' # For Google Colab
import os
oml.config.cache_directory = os.path.expanduser('/content/cache')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `python str(base_dir)+"/verify.py"'

# %%
path = str(base_dir)+"/verify_colab.py"
# !python "/content/drive/My Drive/assignment-3-RobinvdwUU/verify.py"
# Out:
# Converting: Assignment 3.ipynb
# Traceback (most recent call last):
#   File "/content/drive/My Drive/assignment-3-RobinvdwUU/verify.py", line 18, in <module>
#     (source, meta) = exporter.from_filename(assignment_path)
#   File "/usr/local/lib/python3.6/dist-packages/nbconvert/exporters/exporter.py", line 175, in from_filename
#     modified_date = datetime.datetime.fromtimestamp(os.path.getmtime(filename))
#   File "/usr/lib/python3.6/genericpath.py", line 55, in getmtime
#     return os.stat(filename).st_mtime
# FileNotFoundError: [Errno 2] No such file or directory: 'Assignment 3.ipynb'
