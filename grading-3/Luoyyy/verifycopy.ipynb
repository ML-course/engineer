# %%
# !pip install --quiet openml

# %%
# Load data. It's possible that Colab will ask to switch to a high-RAM runtime
import openml as oml
import os
oml.config.cache_directory = os.path.expanduser('/content/cache')
SVHN = oml.datasets.get_dataset(41081)
X, y, _, _ = SVHN.get_data(dataset_format='array',
    target=SVHN.default_target_attribute)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-68a93ad1d7ed> in <module>()
#       2 import os
#       3 oml.config.cache_directory = os.path.expanduser('/content/cache')
# ----> 4 SVHN = oml.datasets.get_dataset(41081)
#       5 X, y, _, _ = SVHN.get_data(dataset_format='array',
#       6     target=SVHN.default_target_attribute)
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/functions.py in get_dataset(dataset_id, download_data, version, error_if_multiple)
#     528
#     529     dataset = _create_dataset_from_description(
# --> 530         description, features, qualities, arff_file
#     531     )
#     532     return dataset
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/functions.py in _create_dataset_from_description(description, features, qualities, arff_file)
#    1021         data_file=arff_file,
#    1022         features=features,
# -> 1023         qualities=qualities,
#    1024     )
#    1025
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/dataset.py in __init__(self, name, description, format, data_format, dataset_id, version, creator, contributor, collection_date, upload_date, language, licence, url, default_target_attribute, row_id_attribute, ignore_attribute, version_label, citation, tag, visibility, original_data_url, paper_url, update_comment, md5_checksum, data_file, features, qualities, dataset)
#     181
#     182         if data_file is not None:
# --> 183             self.data_pickle_file = self._create_pickle_in_cache(data_file)
#     184         else:
#     185             self.data_pickle_file = None
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/dataset.py in _create_pickle_in_cache(self, data_file)
#     421         # At this point either the pickle file does not exist, or it had outdated formatting.
#     422         # We parse the data from arff again and populate the cache with a recent pickle file.
# --> 423         X, categorical, attribute_names = self._parse_data_from_arff(data_file)
#     424
#     425         with open(data_pickle_file, "wb") as fh:
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/dataset.py in _parse_data_from_arff(self, arff_file_path)
#     314         """
#     315         try:
# --> 316             data = self._get_arff(self.format)
#     317         except OSError as e:
#     318             logger.critical("Please check that the data file {} is "
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/dataset.py in _get_arff(self, format)
#     293         else:
#     294             with io.open(filename, encoding='utf8') as fh:
# --> 295                 return decode_arff(fh)
#     296
#     297     def _parse_data_from_arff(
#
# /usr/local/lib/python3.6/dist-packages/openml/datasets/dataset.py in decode_arff(fh)
#     286             decoder = arff.ArffDecoder()
#     287             return decoder.decode(fh, encode_nominal=True,
# --> 288                                   return_type=return_type)
#     289
#     290         if filename[-3:] == ".gz":
#
# /usr/local/lib/python3.6/dist-packages/arff.py in decode(self, s, encode_nominal, return_type)
#     890         try:
#     891             return self._decode(s, encode_nominal=encode_nominal,
# --> 892                                 matrix_type=return_type)
#     893         except ArffException as e:
#     894             e.line = self._current_line
#
# /usr/local/lib/python3.6/dist-packages/arff.py in _decode(self, s, encode_nominal, matrix_type)
#     867
#     868         # Alter the data object
# --> 869         obj['data'] = data.decode_rows(stream(), self._conversors)
#     870         if obj['description'].endswith('\n'):
#     871             obj['description'] = obj['description'][:-1]
#
# /usr/local/lib/python3.6/dist-packages/arff.py in decode_rows(self, stream, conversors)
#     516     """Mixin to return a list from decode_rows instead of a generator"""
#     517     def decode_rows(self, stream, conversors):
# --> 518         return list(super(_DataListMixin, self).decode_rows(stream, conversors))
#     519
#     520
#
# /usr/local/lib/python3.6/dist-packages/arff.py in decode_rows(self, stream, conversors)
#     457     def decode_rows(self, stream, conversors):
#     458         for row in stream:
# --> 459             values = _parse_values(row)
#     460
#     461             if isinstance(values, dict):
#
# /usr/local/lib/python3.6/dist-packages/arff.py in _parse_values(s)
#     266 def _parse_values(s):
#     267     '''(INTERNAL) Split a line into a list of values'''
# --> 268     if not _RE_NONTRIVIAL_DATA.search(s):
#     269         # Fast path for trivial cases (unfortunately we have to handle missing
#     270         # values because of the empty string case :(.)
#
# KeyboardInterrupt:

# %%
# If the kernel dies loading the data, run this
# Replace '/content/cache' with the cache directory you specified in your notebook
from google_drive_downloader import GoogleDriveDownloader as gdd
gdd.download_file_from_google_drive(file_id='1zZRRe3ffmuAf1x4yZmYwG_rLiuggep2A',
             dest_path='/content/cache/org/openml/www/datasets/41081/dataset.pkl.py3')

# %%
# Run verify.py
# Update 'my_directory' with the path to your files

import os
import nbformat
from nbconvert import PythonExporter, HTMLExporter
from nbconvert.preprocessors import CellExecutionError, ExecutePreprocessor
from traitlets.config import Config
import warnings
warnings.filterwarnings('ignore') 

from google.colab import drive
drive.mount('/content/drive')

# Replace 'my_directory' with the directory on Google Drive where you have
# uploaded your assignment and model files.
# Most likely: /content/drive/My Drive/Colab Notebooks/assignment-3-githubname
# %cd /content/drive/My Drive/assignment-3-Luoyyy/
basedir = '/content/drive/My Drive/assignment-3-Luoyyy/' 

# Convert notebook to python
assignment_path = basedir + 'Assignment 3.ipynb'
export_path = basedir + 'solution.py'
template_path = basedir + 'submit/Template.ipynb'
submission_path = basedir + 'Submission.html'

print("Converting: {0}".format(assignment_path))
exporter = PythonExporter()
# source is a tuple of python source code, meta contains metadata
(source, meta) = exporter.from_filename(assignment_path)
with open(export_path, 'w+') as fh:
    fh.writelines(source)
    fh.writelines("last_edit = '{}'".format(meta['metadata']['modified_date']))
    
# Run solution notebook
with open(template_path) as f:
    snb = nbformat.read(f, as_version=4)
# Already updated to 4000 seconds.
ep = ExecutePreprocessor(timeout=4000, kernel_name='python3')

try:
    print("Running notebook... (may take a while)")
    out = ep.preprocess(snb, {'metadata': {'path': './'}})
except CellExecutionError:
    out = None
    msg = 'Error executing the notebook "%s".\n\n' % template_path
    msg += 'See notebook "%s" for the traceback.' % template_path
    print(msg)
    raise
finally:
    # Save notebook
    with open(template_path, mode='w', encoding='utf-8') as f:
        nbformat.write(snb, f)

# Export as HTML (PDF is too much hassle)
print("All good. Building report.")
c = Config()
c.TagRemovePreprocessor.enabled=True
c.TagRemovePreprocessor.remove_input_tags = set(["hide_input"])
c.preprocessors = ["TagRemovePreprocessor"]

html_exporter = HTMLExporter(config=c)
html_data, resources = html_exporter.from_notebook_node(snb)
html_data = html_data.replace('</head>', '<style>pre{font-family: "Times New Roman", Times, serif;}</style></head>')

with open(submission_path, "wb") as f:
    f.write(html_data.encode('utf8'))
    f.close()
#Cleanup
#os.remove("solution.py")
print("Done.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/assignment-3-Luoyyy
# Converting: /content/drive/My Drive/assignment-3-Luoyyy/Assignment 3.ipynb
# Running notebook... (may take a while)
# All good. Building report.
# Done.
