# %%
#A notebook to run the verify.py seperately. You can ignore it :)

# %%
# Uncomment the following line to run in Google Colab
#!pip install --quiet openml

# %%
# Uncomment the following line to run in Google Colab
# %tensorflow_version 2.x
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU') # Check whether GPUs are available
# Out:
# []

# %%
#Uncomment to link Colab notebook to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/assignment-3-RosenV95
# !python ./verify.py
# Out:
# /content/drive/My Drive/assignment-3-RosenV95
# Converting: Assignment 3.ipynb
# Running notebook... (may take a while)
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# 2020-04-19 19:25:53.803440: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# tcmalloc: large alloc 2440167424 bytes == 0x6e54000 @  0x7fb88bd571e7 0x5929fc 0x4ce180 0x567322 0x5a5611 0x4de436 0x4e00e8 0x5ec32e 0x50a9da 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x5167b9
# tcmalloc: large alloc 2440134656 bytes == 0x98574000 @  0x7fb88bd571e7 0x5929fc 0x5eb636 0x4df2b7 0x5ec32e 0x50a9da 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3 0x50d390 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x5167b9 0x5678ee 0x51171e 0x508245
# tcmalloc: large alloc 2440167424 bytes == 0x6e54000 @  0x7fb88bd571e7 0x5929fc 0x4ce180 0x567322 0x5a5611 0x4de436 0x4e00e8 0x5ec32e 0x50a9da 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x5167b9 0x5678ee 0x51171e 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9
# tcmalloc: large alloc 2440134656 bytes == 0x98574000 @  0x7fb88bd571e7 0x5929fc 0x5eb636 0x4df2b7 0x5ec32e 0x50a9da 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x5167b9 0x5678ee 0x51171e 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9
# tcmalloc: large alloc 2440126464 bytes == 0x6e54000 @  0x7fb88bd571e7 0x7fb8833195e1 0x7fb88337de88 0x7fb88337e147 0x7fb883416118 0x50ac25 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x509642 0x595311 0x5a067e
# tcmalloc: large alloc 2440126464 bytes == 0x129cf8000 @  0x7fb88bd571e7 0x7fb8833195e1 0x7fb88337de88 0x7fb88337e147 0x7fb883416118 0x50ac25 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x5096b7 0x595311
# All good. Building report.
# Done.

# %%
array = []
while True:
  array.append('Test')
