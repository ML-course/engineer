# %%
# Fill in your name using the format below and student ID number
your_name = "Kaidong, Wu"
student_id = "1457721"

# %%
# Before submission, set this to True so that you can render and verify this notebook without training deep learning models.
# Any deep learning models will be trained from file instead.
stop_training = True

# %%
# Uncomment the following line to run in Google Colab
# !pip install --quiet openml

# %%
# Uncomment the following line to run in Google Colab
#%tensorflow_version 2.x
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU') # Check whether GPUs are available
# Out:
# []

# %%
# %matplotlib inline
import openml as oml
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
from packaging import version
import sklearn
import tensorflow
sklearn_version = sklearn.__version__
tensorflow_version = tensorflow.__version__
if version.parse(sklearn_version) < version.parse("0.22.0"):
    print("scikit-learn is outdated. Please update now!")
if version.parse(tensorflow_version) < version.parse("2.1.0"):
    print("Tensorflow is outdated. This is version {}. Please update to 2.1.".format(tensorflow_version))
else:
    print("Hi{}, Looks good. You may continue :)".format(your_name.split(",")[1]))
# Out:
# Hi Wu, Looks good. You may continue :)

# %% [markdown]
# # Assignment 3

# %% [markdown]
# ### Choice of libraries
# We recommend to use Tensorflow in this assignment since that is what we covered in the labs. If you feel confident using PyTorch (and Skorch for the scikit-learn wrapper), that is allowed too, as long as you are able to implement the requested functions and return the requested data. Read the assignment carefully and ensure that you can. Note that you may also need to do a bit more work to implement certain helper functions and wrappers.

# %% [markdown]
# ### Storing and submitting files
# You must be able to store your models and submit them to GitHub Classroom. The evaluation functions used in this notebook will automatically store models for you.
#
# If you want to run and solve the notebook on your local machine/laptop, fill in the path 'base_dir' to your assignment folder into the next cell.
#
# If you use Colab, we recommend that you link it to your Google Drive:
# * Upload the assignment folder to your Google Drive (+ New > Folder Upload)
# * Open Colab in a browser, open the 'Files' menu in the left sidebar, and click 'Mount Drive'
#   * At this point you may need to authenticate
# * Fill in the path to your assignment folder below
#   * It's likely '/content/drive/My Drive/assignment-3-yourname'

# %%
#base_dir = '/content/drive/My Drive/TestAssignment' # For Google Colab
base_dir = 'D:\\clone\\assignment-3-Fakak'

# %%
#Uncomment to link Colab notebook to Google Drive
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ### Using GPUs
# While you can solve this assignment on a CPU, using a GPU will speed things up training quite a bit. If you have a local GPU, you can use that. If you don't, we recommend Google Colab. When you are in Colab:
# * In Runtime > Change runtime type, select the GPU under Hardware Accelerator
# * Run the 3rd cell on the top of this notebook to check that the GPU is found.
#
# Note that Colab may not always have GPUs ready all the time, and may deny you a GPU when you have used them a lot. When you are temporarily 'locked out', you can switch to a non-GPU runtime or to a local instance of Jupyter running on your machine.

# %% [markdown]
# ### Constraints
# * Your stored models should not be larger than 100MB when stored in file. GitHub will not allow uploading if they are.
# * When questions ask you to provide an explanation, it should be less than 500
# characters long. Some questions have a higher limit. Always answer in full sentences.
# * Don't train for more than 100 epochs, i.e. don't throw excessing computational resources at the problem. If your model hasn't converged by then, think of ways it could be made to converge faster. In this assignment you are not after the last tiny improvement, you can stop when learning curves flatten out. Do at least 5 epochs to get a reasonable learning curve.

# %% [markdown]
# ### Grading
# Grading is based on the following aspects:
# * Correctness in answering the question. Carefully read the question and answer
# what is asked for. Train your models on the correct data. It should be clear on which data should be trained, but ask when in doubt. When something is not defined (e.g. the number of epochs or batch size), you can freely choose them.
# * Clarity of your explanations. Write short but precise descriptions of what you did and why. Give short but clear explanations of the observed performance.
# After your explanation, your approach and model should make perfect sense. Refrain from using symbols as substitute for words in your explanation (e.g. no: "More layers -> more parameters" yes: "More layers mean more parameters").
# * Part of your grade depends on how well your model performs. When the question says 'you should at least get x%', x% will give you a good but not the maximal grade. You can get the full grade when you are close to what is the expected maximal performance. You don't need to invest lots of effort into the last tiny improvement, though. Unless specified, we look at the accuracy on the validation set. If your learning curves are very erratic we'll compute a score based on the smoothed curves (i.e. single peaks don't count).
# * The weight of each question is indicated. Take this into account when planning your time.

# %% [markdown]
# ### Other tips
# * Don't wait until the last minute to do the assignment. The models take time to train, most questions will require some thinking, and some require you to read up on some new concepts.
# * Take care that you upload the results as requested. You need to submit not only the notebooks but also the trained models and learning curves (training histories). Be sure to run the verification script and check that all the results are included.
# * We provide an evaluation function that also stored models to disk. After you are done training the model, set the 'train' attribute to False so that the model doesn't train again (and loads from file instead) when you restart and rerun your notebook.
# * Explore. For many questions we'll ask you to explain your model design decisions. You cannot magically know the best solutions but you can experiment
# based on your understanding and make decisions based on both your knowledge and experiments. Your explanation is at least as important as the performance of your model.
# * Be original. We will check for plagiarism between student submissions.

# %% [markdown]
# ### Data
# The [Street View House Numbers Dataset](https://www.openml.org/d/41081) contains 32-by-32 RGB images centered around a single digit of a house number appearing in Google Street View. Many of the images do contain some distractors at the sides. It consists of 10 classes, 1 for each digit. Digit '1' has label 1, '9' has label 9 and '0' has label 10. Your goal is to build models that recognize the correct digit.

# %% [markdown]
# If you use Colab, uncomment the following to cache the dataset inside the VM. This will make reloading faster if you need to restart your notebook. After longer periods of inactivity, your VM may be recycled and the cache lost, in which case the dataset will be downloaded again. Also note that this dataset is about 1Gb large, and will take even more space in memory. You may need to switch to a high-RAM environment (Colab will ask you if you hit the limit).

# %%
# Use OpenML caching in Colab
# On your local machine, it will store data in a hidden folder '~/.openml'
#import os
#oml.config.cache_directory = os.path.expanduser('/content/cache')

# %%
# Download Streetview data. Takes a while (several minutes), and quite a bit of
# memory when it needs to download. After caching it loads faster.
SVHN = oml.datasets.get_dataset(41081)
X, y, _, _ = SVHN.get_data(dataset_format='array',
    target=SVHN.default_target_attribute)

# %% [markdown]
# Reshape, sample and split the data

# %%
from tensorflow.keras.utils import to_categorical

Xr = X.reshape((len(X),32,32,3))
Xr = Xr / 255.
yr = to_categorical(y)

# %%
# DO NOT EDIT. DO NOT OVERWRITE THESE VARIABLES.
from sklearn.model_selection import train_test_split
# We do an 80-20 split for the training and test set, and then again a 80-20 split into training and validation data
X_train_all, X_test, y_train_all, y_test = train_test_split(Xr,yr, stratify=yr, train_size=0.8, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train_all,y_train_all, stratify=y_train_all, train_size=0.8, random_state=1)
evaluation_split = X_train, X_val, y_train, y_val

# %% [markdown]
# Check the formatting - and what the data looks like

# %%
from random import randint

# Takes a list of row ids, and plots the corresponding images
# Use grayscale=True for plotting grayscale images
def plot_images(X, y, grayscale=False):
    fig, axes = plt.subplots(1, len(X),  figsize=(10, 5))
    for n in range(len(X)):
        if grayscale:
            axes[n].imshow(X[n], cmap='gray')
        else:
            axes[n].imshow(X[n])
        axes[n].set_xlabel((np.argmax(y[n])+1)%10) # Label is index+1
        axes[n].set_xticks(()), axes[n].set_yticks(())
    plt.show();

#images = [randint(0,len(X_test)) for i in range(5)]
images=[0,1]
print(images)
X_random = [X_test[i] for i in images]
#X_random = X_test[0]
y_random = [y_test[i] for i in images]
#y_random = y_test[0]
plot_images(X_random, y_random)
# Out:
# [0, 1]

# %% [markdown]
# ### Evaluation harness
# We provide an evaluation function 'run_evaluation' that you should use to
# evaluate all your models. It also stores the trained models to disk so that
# your submission can be quickly verified, as well as to avoid having to train
# them over and over again. Your last run of the evaluation function (the last one
# stored to file), is the one that will be evaluated. The 'train' argument indicates whether to train or to load from disk. We have provided helper functions for saving and loading models to/from file, assuming you use TensorFlow. If you use PyTorch you'll have to adapt them.

# %%
import os
import pickle
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model # for use with tensorflow

def shout(text, verbose=1):
    """ Prints text in red. Just for fun.
    """
    if verbose>0:
        print('\033[91m'+text+'\x1b[0m')

def load_model_from_file(base_dir, name, extension='.h5'):
    """ Loads a model from a file. The returned model must have a 'fit' and 'summary'
    function following the Keras API. Don't change if you use TensorFlow. Otherwise,
    adapt as needed. 
    Keyword arguments:
    base_dir -- Directory where the models are stored
    name -- Name of the model, e.g. 'question_1_1'
    extension -- the file extension
    """
    try:
        model = load_model(os.path.join(base_dir, name+extension))
    except OSError:
        shout("Saved model could not be found. Was it trained and stored correctly? Is the base_dir correct?")
        return False
    return model

def save_model_to_file(model, base_dir, name, extension='.h5'):
    """ Saves a model to file. Don't change if you use TensorFlow. Otherwise,
    adapt as needed. 
    Keyword arguments:
    model -- the model to be saved
    base_dir -- Directory where the models should be stored
    name -- Name of the model, e.g. 'question_1_1'
    extension -- the file extension
    """
    model.save(os.path.join(base_dir, name+extension))

# Helper function to extract min/max from the learning curves
def minMax(x):
    return pd.Series(index=['min','max'],data=[x.min(),x.max()])

# DO NOT EDIT
def run_evaluation(name, model_builder, data, base_dir, train=True, 
                   generator=False, epochs=3, batch_size=32, steps_per_epoch=496, 
                   verbose=1, **kwargs):
    """ Trains and evaluates the given model on the predefined train and test splits,
    stores the trained model and learning curves. Also prints out a summary of the 
    model and plots the learning curves.
    Keyword arguments:
    name -- the name of the model to be stored, e.g. 'question_1_1.h5'
    model_builder -- function that returns an (untrained) model. The model must 
                     have a 'fit' function that follows the Keras API. It can wrap
                     a non-Keras model as long as the 'fit' function takes the 
                     same attributes and returns the learning curves (history).
                     It also must have a 'summary' function that prints out a 
                     model summary, and a 'save' function that saves the model 
                     to disk. 
    data -- data split for evaluation. A tuple of either:
            * Numpy arrays (X_train, X_val, y_train, y_val)
            * A data generator and validation data (generator, X_val, y_val)
    base_dir -- the directory to save or read models to/from
    train -- whether or not the data should be trained. If False, the trained model
             will be loaded from disk.
    generator -- whether the data in given as a generator or not
    epochs -- the number of epochs to train for
    batch_size -- the batch size to train with
    steps_per_epoch -- steps per epoch, in case a generator is used (ignored otherwise)
    verbose -- verbosity level, 0: silent, 1: minimal,...
    kwargs -- keyword arguments that should be passed to model_builder.
              Not required, but may help you to adjust its behavior
    """
    model = model_builder(**kwargs)
    if not model:
        shout("No model is returned by the model_builder")
        return
    if not hasattr(model, 'fit'):
        shout("Model is not built correctly")
        return
    learning_curves = {}
    if train and not stop_training: # Train anew
        shout("Training the model", verbose)
        if generator:
            generator, X_val, y_val = data
            history = model.fit(generator, epochs=epochs, batch_size=batch_size,
                              steps_per_epoch=steps_per_epoch, verbose=1, 
                              validation_data=(X_val, y_val))
            learning_curves = history.history
        else:
            X_train, X_val, y_train, y_val = data
            history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,
                              verbose=1, validation_data=(X_val, y_val))
            learning_curves = history.history
        shout("Saving to file", verbose)
        save_model_to_file(model, base_dir, name)
        with open(os.path.join(base_dir, name+'.p'), 'wb') as file_pi:
            pickle.dump(learning_curves, file_pi)
        shout("Model stored in "+base_dir, verbose)
    else: # Load from file
        shout("Loading model from file", verbose)
        model = load_model_from_file(base_dir, name)
        if not model:
            shout("Model not found")
            return
        learning_curves = None
        try:
            learning_curves = pickle.load(open(os.path.join(base_dir, name+'.p'), "rb"))
        except FileNotFoundError:
            shout("Learning curves not found")
            return
        shout("Success!", verbose)
    # Report
    print(model.summary())
    lc = pd.DataFrame(learning_curves)
    lc.plot(lw=2,style=['b:','r:','b-','r-']);
    plt.xlabel('epochs');
    print(lc.apply(minMax))

# %%
# Toy usage example
# Remove before submission
from tensorflow.keras import models
from tensorflow.keras import layers 

def build_toy_model():
    model = models.Sequential()
    model.add(layers.Reshape((3072,), input_shape=(32,32,3)))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# First build and store
run_evaluation("toy_example", build_toy_model, evaluation_split, base_dir, 
               train=True, epochs=3, batch_size=32)
# Out:
# Loading model from file
# Success!
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                30730
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# =================================================================
# Total params: 30,840
# Trainable params: 30,840
# Non-trainable params: 0
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  2.170817  0.190592  2.164226      0.187827
# max  2.243367  0.197595  2.198731      0.200667

# %%
# Toy usage example
# Remove before submission
# With train=False: load from file and report the same results without rerunning
run_evaluation("toy_example", build_toy_model, evaluation_split, base_dir, 
               train=False)
# Out:
# Loading model from file
# Success!
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                30730
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# =================================================================
# Total params: 30,840
# Trainable params: 30,840
# Non-trainable params: 0
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  2.170817  0.190592  2.164226      0.187827
# max  2.243367  0.197595  2.198731      0.200667

# %% [markdown]
# ## Part 1. Dense networks (10 points)
#
# ### Question 1.1: Baseline model (4 points)
# - Build a dense network (with only dense layers) of at least 3 layers that is shaped like a pyramid: The first layer must have many nodes, and every subsequent layer must have increasingly fewer nodes, e.g. half as many. Implement a function 'build_model_1_1' that returns this model.
# - You can explore different settings, but don't use any preprocessing or regularization yet. You should be able to achieve at least 70% accuracy, but more is of course better. Unless otherwise stated, you can use accuracy as the evaluation metric in all questions.
# * Add a small description of your design choices (max. 500 characters) in 'answer_q_1_1': explain what you did and also why. Also discuss the performance of the model. Is it working well? Both the performance of the model and your explanations matter.
# - The name of the model should be 'model_1_1'. Evaluate it using the 'run_evaluation' function. For this question, you should not use more than 50 epochs.

# %%
def build_model_1_1():
    model = models.Sequential()
    model.add(layers.Reshape((3072,), input_shape=(32,32,3)))
    model.add(layers.Dense(100, activation='relu'))
    model.add(layers.Dense(50, activation='relu'))
    model.add(layers.Dense(25, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

run_evaluation("model_1_1", build_model_1_1, evaluation_split, base_dir, 
               train=True, epochs=50, batch_size=128)
answer_q_1_1 = """
  I built a neural network as the question description. The activation function of hidden layers are "relu", it is in most cases the default option, "softmax" is the activation function of output layer because the output values, can be seen as the "probability", thus ideal for classification problem.
  The model performs well without overfitting according to the plot.
               """
print("Answer is {} characters long".format(len(answer_q_1_1)))
# Out:
# Training the model
# Train on 63544 samples, validate on 15887 samples
# Epoch 1/50
# 63544/63544 [==============================] - 4s 58us/sample - loss: 2.2364 - accuracy: 0.1903 - val_loss: 2.1776 - val_accuracy: 0.2150
# Epoch 2/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 2.0009 - accuracy: 0.2863 - val_loss: 1.8637 - val_accuracy: 0.3391
# Epoch 3/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 1.7139 - accuracy: 0.4067 - val_loss: 1.6552 - val_accuracy: 0.4467
# Epoch 4/50
# 63544/63544 [==============================] - 3s 48us/sample - loss: 1.5680 - accuracy: 0.4698 - val_loss: 1.5417 - val_accuracy: 0.4967
# Epoch 5/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 1.4697 - accuracy: 0.5100 - val_loss: 1.3880 - val_accuracy: 0.5436
# Epoch 6/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 1.3865 - accuracy: 0.5437 - val_loss: 1.3369 - val_accuracy: 0.5728
# Epoch 7/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 1.3211 - accuracy: 0.5710 - val_loss: 1.4250 - val_accuracy: 0.5355
# Epoch 8/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 1.2755 - accuracy: 0.5868 - val_loss: 1.5006 - val_accuracy: 0.5156
# Epoch 9/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 1.2409 - accuracy: 0.6005 - val_loss: 1.4284 - val_accuracy: 0.5440
# Epoch 10/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 1.2159 - accuracy: 0.6114 - val_loss: 1.2614 - val_accuracy: 0.5884
# Epoch 11/50
# 63544/63544 [==============================] - 3s 45us/sample - loss: 1.1826 - accuracy: 0.6220 - val_loss: 1.1897 - val_accuracy: 0.6245
# Epoch 12/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 1.1631 - accuracy: 0.6324 - val_loss: 1.2007 - val_accuracy: 0.6184
# Epoch 13/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 1.1406 - accuracy: 0.6410 - val_loss: 1.6070 - val_accuracy: 0.5088
# Epoch 14/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 1.1158 - accuracy: 0.6504 - val_loss: 1.0655 - val_accuracy: 0.6751
# Epoch 15/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 1.0946 - accuracy: 0.6572 - val_loss: 1.1363 - val_accuracy: 0.6396
# Epoch 16/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 1.0745 - accuracy: 0.6639 - val_loss: 1.0868 - val_accuracy: 0.6622
# Epoch 17/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 1.0541 - accuracy: 0.6731 - val_loss: 1.2851 - val_accuracy: 0.6014
# Epoch 18/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 1.0363 - accuracy: 0.6789 - val_loss: 1.1773 - val_accuracy: 0.6384
# Epoch 19/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 1.0256 - accuracy: 0.6821 - val_loss: 1.0221 - val_accuracy: 0.6864
# Epoch 20/50
# 63544/63544 [==============================] - 3s 48us/sample - loss: 1.0076 - accuracy: 0.6886 - val_loss: 1.0258 - val_accuracy: 0.6857
# Epoch 21/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.9975 - accuracy: 0.6909 - val_loss: 1.0752 - val_accuracy: 0.6592
# Epoch 22/50
# 63544/63544 [==============================] - 3s 48us/sample - loss: 0.9792 - accuracy: 0.6999 - val_loss: 0.9675 - val_accuracy: 0.7080
# Epoch 23/50
# 63544/63544 [==============================] - 3s 45us/sample - loss: 0.9714 - accuracy: 0.7024 - val_loss: 1.0925 - val_accuracy: 0.6542
# Epoch 24/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 0.9652 - accuracy: 0.7024 - val_loss: 1.1234 - val_accuracy: 0.6456
# Epoch 25/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 0.9491 - accuracy: 0.7096 - val_loss: 1.0250 - val_accuracy: 0.6875
# Epoch 26/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.9455 - accuracy: 0.7114 - val_loss: 1.0601 - val_accuracy: 0.6698
# Epoch 27/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.9366 - accuracy: 0.7157 - val_loss: 0.9586 - val_accuracy: 0.7097
# Epoch 28/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 0.9296 - accuracy: 0.7171 - val_loss: 1.0271 - val_accuracy: 0.6795
# Epoch 29/50
# 63544/63544 [==============================] - 3s 44us/sample - loss: 0.9220 - accuracy: 0.7188 - val_loss: 0.9950 - val_accuracy: 0.7003
# Epoch 30/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.9169 - accuracy: 0.7214 - val_loss: 0.9172 - val_accuracy: 0.7252
# Epoch 31/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.9135 - accuracy: 0.7223 - val_loss: 1.1434 - val_accuracy: 0.6516
# Epoch 32/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.9030 - accuracy: 0.7240 - val_loss: 0.9418 - val_accuracy: 0.7203
# Epoch 33/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.8985 - accuracy: 0.7262 - val_loss: 0.9456 - val_accuracy: 0.7144
# Epoch 34/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 0.8917 - accuracy: 0.7278 - val_loss: 0.9393 - val_accuracy: 0.7229
# Epoch 35/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.8911 - accuracy: 0.7275 - val_loss: 0.9140 - val_accuracy: 0.7281
# Epoch 36/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.8825 - accuracy: 0.7305 - val_loss: 0.9716 - val_accuracy: 0.7060
# Epoch 37/50
# 63544/63544 [==============================] - 3s 50us/sample - loss: 0.8777 - accuracy: 0.7326 - val_loss: 0.9967 - val_accuracy: 0.6982
# Epoch 38/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.8733 - accuracy: 0.7341 - val_loss: 0.9393 - val_accuracy: 0.7151
# Epoch 39/50
# 63544/63544 [==============================] - 3s 45us/sample - loss: 0.8711 - accuracy: 0.7335 - val_loss: 0.9952 - val_accuracy: 0.7055
# Epoch 40/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.8650 - accuracy: 0.7369 - val_loss: 0.9543 - val_accuracy: 0.7159
# Epoch 41/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.8619 - accuracy: 0.7390 - val_loss: 1.0019 - val_accuracy: 0.6949
# Epoch 42/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 0.8539 - accuracy: 0.7395 - val_loss: 1.0613 - val_accuracy: 0.6736
# Epoch 43/50
# 63544/63544 [==============================] - 4s 56us/sample - loss: 0.8555 - accuracy: 0.7393 - val_loss: 1.0408 - val_accuracy: 0.6792
# Epoch 44/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 0.8500 - accuracy: 0.7405 - val_loss: 0.9535 - val_accuracy: 0.7084
# Epoch 45/50
# 63544/63544 [==============================] - 3s 51us/sample - loss: 0.8465 - accuracy: 0.7429 - val_loss: 1.0209 - val_accuracy: 0.6956
# Epoch 46/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.8443 - accuracy: 0.7424 - val_loss: 0.8732 - val_accuracy: 0.7405
# Epoch 47/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.8390 - accuracy: 0.7452 - val_loss: 0.9239 - val_accuracy: 0.7256
# Epoch 48/50
# 63544/63544 [==============================] - 3s 49us/sample - loss: 0.8386 - accuracy: 0.7449 - val_loss: 0.9915 - val_accuracy: 0.6993
# Epoch 49/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.8357 - accuracy: 0.7464 - val_loss: 0.9008 - val_accuracy: 0.7252
# Epoch 50/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.8326 - accuracy: 0.7463 - val_loss: 0.9042 - val_accuracy: 0.7247
# Saving to file
# Model stored in ./
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 3072)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               307300
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_14 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                260
# =================================================================
# Total params: 313,885
# Trainable params: 313,885
# Non-trainable params: 0
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  0.832643  0.190309  0.873217      0.214956
# max  2.236391  0.746396  2.177589      0.740543
# Answer is 387 characters long

# %% [markdown]
# ### Question 1.2: Preprocessing (2 points)
# Rerun the model, but now preprocess the data first by converting the images to
# greyscale. You can use the helper function below. If you want to do additional
# preprocessing, you can do that here, too.
# * Store the preprocessed data as a tuple `preprocessed_split`
# * Rerun and re-evaluate your model using the preprocessed data.
#   * For the remainder of the assignment, always use the preprocessed data
# * Explain what you did and interpret the results in 'answer_q_1_2'. Is the model
#   better, if so, why?

# %%
# Luminance-preserving RGB to greyscale conversion
def rgb2gray(X):
    return np.expand_dims(np.dot(X, [0.2990, 0.5870, 0.1140]), axis=3)

# %%
# Replace with the preprocessed data
preprocessed_split = rgb2gray(X_train), rgb2gray(X_val), y_train, y_val

# Adjusted model
def build_model_1_2():
    model = models.Sequential()
    model.add(layers.Reshape((1024,), input_shape=(32,32,1)))
    model.add(layers.Dense(100, activation='relu'))
    model.add(layers.Dense(50, activation='relu'))
    model.add(layers.Dense(25, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Evaluate. Use a new name 'model_1_2' to not overwrite the previous trained model
run_evaluation("model_1_2", build_model_1_2, preprocessed_split, base_dir, 
               train=True, epochs=50, batch_size=128)
answer_q_1_2 = """
    I convert the RGB images to greyscale and retrain the model. The input shape is (32,32,1) now, and needed to reshape to (1024,), other parameters are exactly the same as 1.1.
    The result shows that greyscale images has better performance than RGB images. This implies that the label of digits depends on its shapes, not colors. The color may even disturb performance. That's maybe because light may blur images and make it difficult for classification.
               """
print("Answer is {} characters long".format(len(answer_q_1_2)))
# Out:
# Training the model
# Train on 63544 samples, validate on 15887 samples
# Epoch 1/50
# 63544/63544 [==============================] - 4s 57us/sample - loss: 2.1440 - accuracy: 0.2267 - val_loss: 1.9503 - val_accuracy: 0.3191
# Epoch 2/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.7552 - accuracy: 0.3943 - val_loss: 1.5791 - val_accuracy: 0.4701
# Epoch 3/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.5578 - accuracy: 0.4709 - val_loss: 1.6486 - val_accuracy: 0.4446
# Epoch 4/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.4197 - accuracy: 0.5338 - val_loss: 1.3466 - val_accuracy: 0.5659
# Epoch 5/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.3115 - accuracy: 0.5776 - val_loss: 1.3519 - val_accuracy: 0.5576
# Epoch 6/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 1.2351 - accuracy: 0.6070 - val_loss: 1.4064 - val_accuracy: 0.5425
# Epoch 7/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 1.1825 - accuracy: 0.6265 - val_loss: 1.2641 - val_accuracy: 0.5948
# Epoch 8/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.1379 - accuracy: 0.6399 - val_loss: 1.2404 - val_accuracy: 0.6053
# Epoch 9/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.0985 - accuracy: 0.6551 - val_loss: 1.1820 - val_accuracy: 0.6293
# Epoch 10/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 1.0649 - accuracy: 0.6677 - val_loss: 1.2641 - val_accuracy: 0.6045
# Epoch 11/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 1.0324 - accuracy: 0.6782 - val_loss: 1.2838 - val_accuracy: 0.5956
# Epoch 12/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.9999 - accuracy: 0.6898 - val_loss: 1.2307 - val_accuracy: 0.6231
# Epoch 13/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.9838 - accuracy: 0.6946 - val_loss: 1.1229 - val_accuracy: 0.6492
# Epoch 14/50
# 63544/63544 [==============================] - 3s 40us/sample - loss: 0.9585 - accuracy: 0.7024 - val_loss: 1.2422 - val_accuracy: 0.6228
# Epoch 15/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.9421 - accuracy: 0.7085 - val_loss: 0.9516 - val_accuracy: 0.7093
# Epoch 16/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.9236 - accuracy: 0.7150 - val_loss: 1.0338 - val_accuracy: 0.6909
# Epoch 17/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.9066 - accuracy: 0.7209 - val_loss: 0.9862 - val_accuracy: 0.6977
# Epoch 18/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.8920 - accuracy: 0.7247 - val_loss: 0.9367 - val_accuracy: 0.7176
# Epoch 19/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.8800 - accuracy: 0.7305 - val_loss: 0.9842 - val_accuracy: 0.7040
# Epoch 20/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.8705 - accuracy: 0.7339 - val_loss: 0.8979 - val_accuracy: 0.7288
# Epoch 21/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.8583 - accuracy: 0.7358 - val_loss: 1.0708 - val_accuracy: 0.6733
# Epoch 22/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.8469 - accuracy: 0.7414 - val_loss: 1.1141 - val_accuracy: 0.6700
# Epoch 23/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.8329 - accuracy: 0.7449 - val_loss: 0.9884 - val_accuracy: 0.6952
# Epoch 24/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.8268 - accuracy: 0.7462 - val_loss: 0.9418 - val_accuracy: 0.7210
# Epoch 25/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.8192 - accuracy: 0.7503 - val_loss: 0.9101 - val_accuracy: 0.7210
# Epoch 26/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.8107 - accuracy: 0.7519 - val_loss: 0.9331 - val_accuracy: 0.7171
# Epoch 27/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7998 - accuracy: 0.7549 - val_loss: 0.9753 - val_accuracy: 0.7060
# Epoch 28/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7969 - accuracy: 0.7573 - val_loss: 0.9884 - val_accuracy: 0.7049
# Epoch 29/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.7865 - accuracy: 0.7593 - val_loss: 0.8473 - val_accuracy: 0.7446
# Epoch 30/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7829 - accuracy: 0.7595 - val_loss: 0.9250 - val_accuracy: 0.7125
# Epoch 31/50
# 63544/63544 [==============================] - 3s 47us/sample - loss: 0.7733 - accuracy: 0.7649 - val_loss: 0.9610 - val_accuracy: 0.7032
# Epoch 32/50
# 63544/63544 [==============================] - 3s 46us/sample - loss: 0.7692 - accuracy: 0.7669 - val_loss: 0.9328 - val_accuracy: 0.7173
# Epoch 33/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.7618 - accuracy: 0.7659 - val_loss: 0.7851 - val_accuracy: 0.7686
# Epoch 34/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.7577 - accuracy: 0.7685 - val_loss: 0.8577 - val_accuracy: 0.7393
# Epoch 35/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7517 - accuracy: 0.7699 - val_loss: 1.0017 - val_accuracy: 0.6933
# Epoch 36/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.7498 - accuracy: 0.7714 - val_loss: 0.8906 - val_accuracy: 0.7334
# Epoch 37/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.7413 - accuracy: 0.7720 - val_loss: 0.8896 - val_accuracy: 0.7293
# Epoch 38/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7352 - accuracy: 0.7756 - val_loss: 0.8132 - val_accuracy: 0.7614
# Epoch 39/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.7329 - accuracy: 0.7766 - val_loss: 0.8287 - val_accuracy: 0.7576
# Epoch 40/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7273 - accuracy: 0.7771 - val_loss: 0.9333 - val_accuracy: 0.7275
# Epoch 41/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7235 - accuracy: 0.7794 - val_loss: 0.8443 - val_accuracy: 0.7483
# Epoch 42/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.7211 - accuracy: 0.7808 - val_loss: 1.0052 - val_accuracy: 0.7091
# Epoch 43/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.7145 - accuracy: 0.7819 - val_loss: 0.8075 - val_accuracy: 0.7620
# Epoch 44/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7132 - accuracy: 0.7835 - val_loss: 0.7764 - val_accuracy: 0.7715
# Epoch 45/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.7067 - accuracy: 0.7841 - val_loss: 0.9258 - val_accuracy: 0.7279
# Epoch 46/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.7049 - accuracy: 0.7858 - val_loss: 0.7776 - val_accuracy: 0.7692
# Epoch 47/50
# 63544/63544 [==============================] - 3s 41us/sample - loss: 0.6982 - accuracy: 0.7881 - val_loss: 0.8426 - val_accuracy: 0.7512
# Epoch 48/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.6946 - accuracy: 0.7882 - val_loss: 0.8485 - val_accuracy: 0.7457
# Epoch 49/50
# 63544/63544 [==============================] - 3s 43us/sample - loss: 0.6940 - accuracy: 0.7892 - val_loss: 0.9042 - val_accuracy: 0.7284
# Epoch 50/50
# 63544/63544 [==============================] - 3s 42us/sample - loss: 0.6900 - accuracy: 0.7883 - val_loss: 0.8419 - val_accuracy: 0.7493
# Saving to file
# Model stored in ./
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_4 (Reshape)          (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_18 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                260
# =================================================================
# Total params: 109,085
# Trainable params: 109,085
# Non-trainable params: 0
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  0.690011  0.226678  0.776381      0.319066
# max  2.144016  0.789201  1.950258      0.771511
# Answer is 476 characters long

# %% [markdown]
# ### Question 1.3: Regularization and tuning (4 points)
# * Regularize the model. You can explore (and combine) different techniques. What works best?
# * Tune other hyperparameters (e.g. learning rate, batch size,...) as you see fit.
# * Explain your findings and final design decisions. Retrain the model again on the preprocessed data and discuss the results.
# * Return your model in function 'build_model_1_3' and write your answer in 'answer_q_1_3'

# %%
#from keras import regularizers

def build_model_1_3():
    model = models.Sequential()
    model.add(layers.Reshape((1024,), input_shape=(32,32,1)))
    model.add(layers.Dense(100, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(50, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(25, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model
run_evaluation("model_1_3", build_model_1_3, preprocessed_split, base_dir, 
               train=True, epochs=50, batch_size=128)
answer_q_1_3 = """
               Since there are no overfitting occurs in 1.1 and 1.2, regularization methods like L1,L2 regularization and dropout do not help(I've tried those methods, they are indeed lower the performance a little). So I only use batch normalization, which increase the "capacity" of nerual network. The result shows that batch normalization increase val accuracy by 1%.
               """
print("Answer is {} characters long".format(len(answer_q_1_3)))
# Out:
# Training the model
# Train on 63544 samples, validate on 15887 samples
# Epoch 1/50
# 63544/63544 [==============================] - 7s 103us/sample - loss: 1.4881 - accuracy: 0.5260 - val_loss: 2.5886 - val_accuracy: 0.2852
# Epoch 2/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 1.0726 - accuracy: 0.6711 - val_loss: 1.5001 - val_accuracy: 0.5320
# Epoch 3/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.9503 - accuracy: 0.7083 - val_loss: 1.5867 - val_accuracy: 0.5240
# Epoch 4/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.8819 - accuracy: 0.7297 - val_loss: 1.9533 - val_accuracy: 0.4471
# Epoch 5/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.8420 - accuracy: 0.7446 - val_loss: 2.0881 - val_accuracy: 0.4527
# Epoch 6/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.8121 - accuracy: 0.7533 - val_loss: 1.7321 - val_accuracy: 0.4793
# Epoch 7/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.7848 - accuracy: 0.7606 - val_loss: 1.3622 - val_accuracy: 0.5773
# Epoch 8/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.7547 - accuracy: 0.7717 - val_loss: 1.7037 - val_accuracy: 0.5309
# Epoch 9/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.7379 - accuracy: 0.7757 - val_loss: 1.1373 - val_accuracy: 0.6497
# Epoch 10/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.7194 - accuracy: 0.7804 - val_loss: 1.0353 - val_accuracy: 0.6823
# Epoch 11/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.7058 - accuracy: 0.7856 - val_loss: 1.0453 - val_accuracy: 0.6783
# Epoch 12/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.6924 - accuracy: 0.7904 - val_loss: 1.0065 - val_accuracy: 0.6935
# Epoch 13/50
# 63544/63544 [==============================] - 4s 58us/sample - loss: 0.6847 - accuracy: 0.7913 - val_loss: 2.0531 - val_accuracy: 0.4530
# Epoch 14/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6720 - accuracy: 0.7961 - val_loss: 0.9417 - val_accuracy: 0.6991
# Epoch 15/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.6691 - accuracy: 0.7962 - val_loss: 1.0993 - val_accuracy: 0.6598
# Epoch 16/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6591 - accuracy: 0.7988 - val_loss: 1.2313 - val_accuracy: 0.6353
# Epoch 17/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6531 - accuracy: 0.8014 - val_loss: 1.1402 - val_accuracy: 0.6541
# Epoch 18/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6448 - accuracy: 0.8032 - val_loss: 1.0378 - val_accuracy: 0.6752
# Epoch 19/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.6390 - accuracy: 0.8046 - val_loss: 1.1456 - val_accuracy: 0.6459
# Epoch 20/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6348 - accuracy: 0.8073 - val_loss: 0.8626 - val_accuracy: 0.7294
# Epoch 21/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6299 - accuracy: 0.8075 - val_loss: 1.1312 - val_accuracy: 0.6517
# Epoch 22/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.6236 - accuracy: 0.8081 - val_loss: 0.8436 - val_accuracy: 0.7404
# Epoch 23/50
# 63544/63544 [==============================] - 5s 71us/sample - loss: 0.6181 - accuracy: 0.8116 - val_loss: 0.7361 - val_accuracy: 0.7753
# Epoch 24/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.6147 - accuracy: 0.8107 - val_loss: 0.8694 - val_accuracy: 0.7336
# Epoch 25/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.6134 - accuracy: 0.8116 - val_loss: 1.0717 - val_accuracy: 0.6784
# Epoch 26/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.6023 - accuracy: 0.8159 - val_loss: 0.8440 - val_accuracy: 0.7411
# Epoch 27/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.6019 - accuracy: 0.8152 - val_loss: 0.8514 - val_accuracy: 0.7392
# Epoch 28/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.5967 - accuracy: 0.8167 - val_loss: 1.0679 - val_accuracy: 0.6652
# Epoch 29/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5977 - accuracy: 0.8169 - val_loss: 0.7766 - val_accuracy: 0.7561
# Epoch 30/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5915 - accuracy: 0.8191 - val_loss: 0.8707 - val_accuracy: 0.7319
# Epoch 31/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5892 - accuracy: 0.8183 - val_loss: 0.8048 - val_accuracy: 0.7570
# Epoch 32/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.5873 - accuracy: 0.8202 - val_loss: 0.8914 - val_accuracy: 0.7300
# Epoch 33/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5847 - accuracy: 0.8208 - val_loss: 0.8937 - val_accuracy: 0.7207
# Epoch 34/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5830 - accuracy: 0.8208 - val_loss: 0.7622 - val_accuracy: 0.7684
# Epoch 35/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5793 - accuracy: 0.8222 - val_loss: 0.8299 - val_accuracy: 0.7466
# Epoch 36/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.5777 - accuracy: 0.8238 - val_loss: 1.0728 - val_accuracy: 0.6823
# Epoch 37/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5769 - accuracy: 0.8227 - val_loss: 0.9769 - val_accuracy: 0.7042
# Epoch 38/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5719 - accuracy: 0.8251 - val_loss: 0.8721 - val_accuracy: 0.7296
# Epoch 39/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5712 - accuracy: 0.8246 - val_loss: 0.9864 - val_accuracy: 0.7054
# Epoch 40/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.5687 - accuracy: 0.8247 - val_loss: 0.8206 - val_accuracy: 0.7498
# Epoch 41/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5651 - accuracy: 0.8250 - val_loss: 0.8160 - val_accuracy: 0.7537
# Epoch 42/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.5631 - accuracy: 0.8272 - val_loss: 0.9318 - val_accuracy: 0.7199
# Epoch 43/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5609 - accuracy: 0.8264 - val_loss: 0.7966 - val_accuracy: 0.7510
# Epoch 44/50
# 63544/63544 [==============================] - 4s 61us/sample - loss: 0.5583 - accuracy: 0.8270 - val_loss: 0.7679 - val_accuracy: 0.7656
# Epoch 45/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5560 - accuracy: 0.8267 - val_loss: 1.1265 - val_accuracy: 0.6589
# Epoch 46/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5570 - accuracy: 0.8280 - val_loss: 0.8935 - val_accuracy: 0.7190
# Epoch 47/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5545 - accuracy: 0.8296 - val_loss: 1.0126 - val_accuracy: 0.6999
# Epoch 48/50
# 63544/63544 [==============================] - 4s 60us/sample - loss: 0.5572 - accuracy: 0.8268 - val_loss: 0.7727 - val_accuracy: 0.7605
# Epoch 49/50
# 63544/63544 [==============================] - 4s 62us/sample - loss: 0.5568 - accuracy: 0.8289 - val_loss: 0.9224 - val_accuracy: 0.7149
# Epoch 50/50
# 63544/63544 [==============================] - 4s 59us/sample - loss: 0.5523 - accuracy: 0.8298 - val_loss: 0.6966 - val_accuracy: 0.7891
# Saving to file
# Model stored in ./
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_5 (Reshape)          (None, 1024)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 100)               102500
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dense_21 (Dense)             (None, 50)                5050
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50)                200
# _________________________________________________________________
# dense_22 (Dense)             (None, 25)                1275
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25)                100
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                260
# =================================================================
# Total params: 109,785
# Trainable params: 109,435
# Non-trainable params: 350
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  0.552335  0.525998  0.696623      0.285202
# max  1.488126  0.829787  2.588563      0.789073
# Answer is 388 characters long

# %% [markdown]
# ## Part 2. Convolutional neural networks (10 points)
# ### Question 2.1: Design a ConvNet (7 points)
# - Build a sequential convolutional neural network. Try to achieve the best validation accuracy you can. You should be able to get at least 90% accuracy. You can use any depth, any combination of layers, and any kind of regularization and tuning.
# - Add a description of your design choices in 'answer_q_2_1': explain what you did and also why. Also discuss the performance of the model. Is it working well? Both the performance of the model and your explanations matter.
# - You are allowed **800** characters for this answer (but don’t ramble).
# - The name of the model should be 'model_2_1'. Evaluate it using the 'run_evaluation' function and the preprocessed data.

# %%
preprocessed_split = rgb2gray(X_train), rgb2gray(X_val), y_train, y_val


def build_model_2_1():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 1)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Dropout(0.1))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dropout(0.5))  
  model.add(layers.Dense(10, activation='softmax'))
  model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
  return model
run_evaluation("model_2_1", build_model_2_1, preprocessed_split, base_dir, 
               train=True, epochs=50, batch_size=128)
answer_q_2_1 = """
               I construct a VGG-like model(I remove a maxpooling layer for the size reason), at first setting, the model overfits begins from about 15 epochs.
               Then I use an common approach used in the lab that gradually increase the amount of dropout and add batchnormalizations after dense layer. The accuracy reachs 95% without overfitting.
               """
print("Answer is {} characters long".format(len(answer_q_2_1)))
# Out:
# Training the model
# Train on 63544 samples, validate on 15887 samples
# Epoch 1/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 1.8505 - accuracy: 0.4000 - val_loss: 0.6795 - val_accuracy: 0.7883
# Epoch 2/50
# 63544/63544 [==============================] - 18s 283us/sample - loss: 0.6834 - accuracy: 0.7966 - val_loss: 0.6871 - val_accuracy: 0.8205
# Epoch 3/50
# 63544/63544 [==============================] - 19s 292us/sample - loss: 0.4898 - accuracy: 0.8600 - val_loss: 0.3463 - val_accuracy: 0.8982
# Epoch 4/50
# 63544/63544 [==============================] - 19s 299us/sample - loss: 0.4099 - accuracy: 0.8837 - val_loss: 0.3578 - val_accuracy: 0.8916
# Epoch 5/50
# 63544/63544 [==============================] - 19s 304us/sample - loss: 0.3632 - accuracy: 0.8996 - val_loss: 0.3425 - val_accuracy: 0.9037
# Epoch 6/50
# 63544/63544 [==============================] - 20s 310us/sample - loss: 0.3279 - accuracy: 0.9095 - val_loss: 0.2530 - val_accuracy: 0.9274
# Epoch 7/50
# 63544/63544 [==============================] - 20s 315us/sample - loss: 0.3030 - accuracy: 0.9160 - val_loss: 0.2529 - val_accuracy: 0.9264
# Epoch 8/50
# 63544/63544 [==============================] - 20s 318us/sample - loss: 0.2850 - accuracy: 0.9229 - val_loss: 0.2475 - val_accuracy: 0.9293
# Epoch 9/50
# 63544/63544 [==============================] - 20s 318us/sample - loss: 0.2660 - accuracy: 0.9271 - val_loss: 0.2590 - val_accuracy: 0.9279
# Epoch 10/50
# 63544/63544 [==============================] - 20s 319us/sample - loss: 0.2563 - accuracy: 0.9314 - val_loss: 0.2256 - val_accuracy: 0.9376
# Epoch 11/50
# 63544/63544 [==============================] - 20s 318us/sample - loss: 0.2444 - accuracy: 0.9347 - val_loss: 0.2316 - val_accuracy: 0.9369
# Epoch 12/50
# 63544/63544 [==============================] - 21s 327us/sample - loss: 0.2300 - accuracy: 0.9379 - val_loss: 0.2291 - val_accuracy: 0.9377
# Epoch 13/50
# 63544/63544 [==============================] - 21s 332us/sample - loss: 0.2222 - accuracy: 0.9404 - val_loss: 0.2314 - val_accuracy: 0.9405
# Epoch 14/50
# 63544/63544 [==============================] - 22s 338us/sample - loss: 0.2102 - accuracy: 0.9449 - val_loss: 0.2027 - val_accuracy: 0.9426
# Epoch 15/50
# 63544/63544 [==============================] - 20s 322us/sample - loss: 0.2062 - accuracy: 0.9461 - val_loss: 0.2251 - val_accuracy: 0.9429
# Epoch 16/50
# 63544/63544 [==============================] - 21s 334us/sample - loss: 0.1936 - accuracy: 0.9490 - val_loss: 0.2280 - val_accuracy: 0.9390
# Epoch 17/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.1857 - accuracy: 0.9510 - val_loss: 0.2154 - val_accuracy: 0.9440
# Epoch 18/50
# 63544/63544 [==============================] - 21s 337us/sample - loss: 0.1816 - accuracy: 0.9529 - val_loss: 0.1994 - val_accuracy: 0.9468
# Epoch 19/50
# 63544/63544 [==============================] - 22s 341us/sample - loss: 0.1727 - accuracy: 0.9547 - val_loss: 0.2222 - val_accuracy: 0.9428
# Epoch 20/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.1716 - accuracy: 0.9564 - val_loss: 0.2413 - val_accuracy: 0.9422
# Epoch 21/50
# 63544/63544 [==============================] - 22s 340us/sample - loss: 0.1645 - accuracy: 0.9577 - val_loss: 0.2354 - val_accuracy: 0.9425
# Epoch 22/50
# 63544/63544 [==============================] - 22s 340us/sample - loss: 0.1569 - accuracy: 0.9588 - val_loss: 0.2075 - val_accuracy: 0.9464
# Epoch 23/50
# 63544/63544 [==============================] - 22s 339us/sample - loss: 0.1558 - accuracy: 0.9597 - val_loss: 0.2111 - val_accuracy: 0.9461
# Epoch 24/50
# 63544/63544 [==============================] - 22s 342us/sample - loss: 0.1513 - accuracy: 0.9610 - val_loss: 0.2279 - val_accuracy: 0.9465
# Epoch 25/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.1422 - accuracy: 0.9631 - val_loss: 0.2012 - val_accuracy: 0.9472
# Epoch 26/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.1410 - accuracy: 0.9643 - val_loss: 0.2565 - val_accuracy: 0.9420
# Epoch 27/50
# 63544/63544 [==============================] - 22s 342us/sample - loss: 0.1352 - accuracy: 0.9656 - val_loss: 0.2053 - val_accuracy: 0.9490
# Epoch 28/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.1300 - accuracy: 0.9665 - val_loss: 0.2348 - val_accuracy: 0.9430
# Epoch 29/50
# 63544/63544 [==============================] - 22s 342us/sample - loss: 0.1276 - accuracy: 0.9671 - val_loss: 0.2149 - val_accuracy: 0.9482
# Epoch 30/50
# 63544/63544 [==============================] - 22s 343us/sample - loss: 0.1276 - accuracy: 0.9677 - val_loss: 0.2077 - val_accuracy: 0.9466
# Epoch 31/50
# 63544/63544 [==============================] - 22s 342us/sample - loss: 0.1196 - accuracy: 0.9687 - val_loss: 0.2085 - val_accuracy: 0.9483
# Epoch 32/50
# 63544/63544 [==============================] - 22s 342us/sample - loss: 0.1181 - accuracy: 0.9701 - val_loss: 0.2327 - val_accuracy: 0.9461
# Epoch 33/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.1158 - accuracy: 0.9710 - val_loss: 0.2525 - val_accuracy: 0.9416
# Epoch 34/50
# 63544/63544 [==============================] - 22s 347us/sample - loss: 0.1109 - accuracy: 0.9720 - val_loss: 0.2486 - val_accuracy: 0.9383
# Epoch 35/50
# 63544/63544 [==============================] - 22s 347us/sample - loss: 0.1090 - accuracy: 0.9716 - val_loss: 0.2191 - val_accuracy: 0.9478
# Epoch 36/50
# 63544/63544 [==============================] - 22s 348us/sample - loss: 0.1064 - accuracy: 0.9724 - val_loss: 0.2124 - val_accuracy: 0.9503
# Epoch 37/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.1056 - accuracy: 0.9730 - val_loss: 0.2211 - val_accuracy: 0.9471
# Epoch 38/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.1029 - accuracy: 0.9729 - val_loss: 0.2629 - val_accuracy: 0.9456
# Epoch 39/50
# 63544/63544 [==============================] - 22s 346us/sample - loss: 0.0987 - accuracy: 0.9745 - val_loss: 0.2134 - val_accuracy: 0.9468
# Epoch 40/50
# 63544/63544 [==============================] - 22s 343us/sample - loss: 0.0991 - accuracy: 0.9745 - val_loss: 0.2175 - val_accuracy: 0.9499
# Epoch 41/50
# 63544/63544 [==============================] - 22s 346us/sample - loss: 0.0954 - accuracy: 0.9754 - val_loss: 0.2255 - val_accuracy: 0.9499
# Epoch 42/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.0943 - accuracy: 0.9759 - val_loss: 0.2301 - val_accuracy: 0.9488
# Epoch 43/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.0924 - accuracy: 0.9763 - val_loss: 0.2213 - val_accuracy: 0.9477
# Epoch 44/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.0888 - accuracy: 0.9776 - val_loss: 0.2155 - val_accuracy: 0.9502
# Epoch 45/50
# 63544/63544 [==============================] - 22s 347us/sample - loss: 0.0895 - accuracy: 0.9767 - val_loss: 0.2254 - val_accuracy: 0.9495
# Epoch 46/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.0873 - accuracy: 0.9775 - val_loss: 0.2337 - val_accuracy: 0.9467
# Epoch 47/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.0850 - accuracy: 0.9776 - val_loss: 0.2426 - val_accuracy: 0.9491
# Epoch 48/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.0821 - accuracy: 0.9785 - val_loss: 0.2179 - val_accuracy: 0.9501
# Epoch 49/50
# 63544/63544 [==============================] - 22s 345us/sample - loss: 0.0837 - accuracy: 0.9780 - val_loss: 0.2360 - val_accuracy: 0.9461
# Epoch 50/50
# 63544/63544 [==============================] - 22s 344us/sample - loss: 0.0791 - accuracy: 0.9794 - val_loss: 0.2443 - val_accuracy: 0.9479
# Saving to file
# Model stored in ./
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               524416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                650
# =================================================================
# Total params: 1,659,594
# Trainable params: 1,659,210
# Non-trainable params: 384
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  0.079077  0.399975  0.199440      0.788318
# max  1.850538  0.979432  0.687116      0.950337
# Answer is 375 characters long

# %% [markdown]
# ### Question 2.2: Data Augmentation (3 points)
#
# - Augment the preprocessed training data. You can explore using image shifts, rotations, zooming, flips, etc. What works well, and what does not?
# - Evaluate the model from question 2.1 with the augmented data using the 'run_evaluation' function. Store the new trained model as 'model_2_2'.
# - Add a description of your design choices in 'answer_q_2_2': explain what you did and also why. Also discuss the performance of the model.

# %%
# Note that we build the same untrained model as in question 2.1 but store the 
# trained version as model_2_2. Change attributes as needed to run on augmented
# data
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    rotation_range=15)
it_train = train_datagen.flow(rgb2gray(X_train), y_train, batch_size=128)
augmented_split = it_train, rgb2gray(X_val), y_val


run_evaluation("model_2_2", build_model_2_1, augmented_split, base_dir, 
               train=True, epochs=50, batch_size=None ,generator=True)
answer_q_2_2 = """
               I've tried many combination of parameters, only a few of them improve performance. Some parameters even lower performance like shear=0.5. The idea is that we should make sure augmented data is reasonable in real life. (For example, we don’t often encounter horizontally flipped numbers)
               The parameters in the code that very subtle augment data imporves accuracy a little bit (less than 1%).
               """
print("Answer is {} characters long".format(len(answer_q_2_2)))
# Out:
# Training the model
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 496 steps, validate on 15887 samples
# Epoch 1/50
# 496/496 [==============================] - 32s 64ms/step - loss: 2.5807 - accuracy: 0.1396 - val_loss: 2.3302 - val_accuracy: 0.1918
# Epoch 2/50
# 496/496 [==============================] - 30s 60ms/step - loss: 2.2539 - accuracy: 0.1877 - val_loss: 2.0961 - val_accuracy: 0.2506
# Epoch 3/50
# 496/496 [==============================] - 30s 60ms/step - loss: 1.6770 - accuracy: 0.4253 - val_loss: 1.2632 - val_accuracy: 0.6760
# Epoch 4/50
# 496/496 [==============================] - 30s 60ms/step - loss: 1.1216 - accuracy: 0.6422 - val_loss: 0.6063 - val_accuracy: 0.8263
# Epoch 5/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.8958 - accuracy: 0.7225 - val_loss: 0.4168 - val_accuracy: 0.8732
# Epoch 6/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.7538 - accuracy: 0.7723 - val_loss: 0.3888 - val_accuracy: 0.8819
# Epoch 7/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.6620 - accuracy: 0.8014 - val_loss: 0.3217 - val_accuracy: 0.9030
# Epoch 8/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.5898 - accuracy: 0.8253 - val_loss: 0.2755 - val_accuracy: 0.9177
# Epoch 9/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.5416 - accuracy: 0.8413 - val_loss: 0.3117 - val_accuracy: 0.9063
# Epoch 10/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.5006 - accuracy: 0.8528 - val_loss: 0.2716 - val_accuracy: 0.9204
# Epoch 11/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.4752 - accuracy: 0.8630 - val_loss: 0.2488 - val_accuracy: 0.9267
# Epoch 12/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.4469 - accuracy: 0.8710 - val_loss: 0.2624 - val_accuracy: 0.9219
# Epoch 13/50
# 496/496 [==============================] - 30s 61ms/step - loss: 0.4241 - accuracy: 0.8773 - val_loss: 0.2366 - val_accuracy: 0.9310
# Epoch 14/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.4122 - accuracy: 0.8832 - val_loss: 0.2281 - val_accuracy: 0.9352
# Epoch 15/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.3960 - accuracy: 0.8882 - val_loss: 0.2092 - val_accuracy: 0.9411
# Epoch 16/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.3846 - accuracy: 0.8899 - val_loss: 0.2272 - val_accuracy: 0.9336
# Epoch 17/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.3751 - accuracy: 0.8947 - val_loss: 0.2072 - val_accuracy: 0.9401
# Epoch 18/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.3613 - accuracy: 0.8987 - val_loss: 0.1973 - val_accuracy: 0.9439
# Epoch 19/50
# 496/496 [==============================] - 30s 61ms/step - loss: 0.3585 - accuracy: 0.9004 - val_loss: 0.2120 - val_accuracy: 0.9394
# Epoch 20/50
# 496/496 [==============================] - 31s 62ms/step - loss: 0.3468 - accuracy: 0.9028 - val_loss: 0.1984 - val_accuracy: 0.9440
# Epoch 21/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.3373 - accuracy: 0.9059 - val_loss: 0.1912 - val_accuracy: 0.9458
# Epoch 22/50
# 496/496 [==============================] - 31s 62ms/step - loss: 0.3305 - accuracy: 0.9078 - val_loss: 0.2044 - val_accuracy: 0.9413
# Epoch 23/50
# 496/496 [==============================] - 29s 59ms/step - loss: 0.3197 - accuracy: 0.9095 - val_loss: 0.1907 - val_accuracy: 0.9467
# Epoch 24/50
# 496/496 [==============================] - 29s 59ms/step - loss: 0.3194 - accuracy: 0.9116 - val_loss: 0.1865 - val_accuracy: 0.9461
# Epoch 25/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.3147 - accuracy: 0.9138 - val_loss: 0.2172 - val_accuracy: 0.9369
# Epoch 26/50
# 496/496 [==============================] - 31s 63ms/step - loss: 0.3109 - accuracy: 0.9143 - val_loss: 0.1878 - val_accuracy: 0.9446
# Epoch 27/50
# 496/496 [==============================] - 34s 69ms/step - loss: 0.3013 - accuracy: 0.9169 - val_loss: 0.1788 - val_accuracy: 0.9487
# Epoch 28/50
# 496/496 [==============================] - 33s 67ms/step - loss: 0.3006 - accuracy: 0.9171 - val_loss: 0.1981 - val_accuracy: 0.9442
# Epoch 29/50
# 496/496 [==============================] - 32s 64ms/step - loss: 0.2929 - accuracy: 0.9198 - val_loss: 0.1749 - val_accuracy: 0.9498
# Epoch 30/50
# 496/496 [==============================] - 32s 65ms/step - loss: 0.2892 - accuracy: 0.9207 - val_loss: 0.1851 - val_accuracy: 0.9486
# Epoch 31/50
# 496/496 [==============================] - 34s 69ms/step - loss: 0.2851 - accuracy: 0.9211 - val_loss: 0.1855 - val_accuracy: 0.9482
# Epoch 32/50
# 496/496 [==============================] - 33s 66ms/step - loss: 0.2846 - accuracy: 0.9216 - val_loss: 0.1799 - val_accuracy: 0.9499
# Epoch 33/50
# 496/496 [==============================] - 31s 62ms/step - loss: 0.2817 - accuracy: 0.9237 - val_loss: 0.1717 - val_accuracy: 0.9523
# Epoch 34/50
# 496/496 [==============================] - 33s 67ms/step - loss: 0.2751 - accuracy: 0.9251 - val_loss: 0.1734 - val_accuracy: 0.9525
# Epoch 35/50
# 496/496 [==============================] - 31s 63ms/step - loss: 0.2716 - accuracy: 0.9260 - val_loss: 0.1954 - val_accuracy: 0.9444
# Epoch 36/50
# 496/496 [==============================] - 31s 63ms/step - loss: 0.2714 - accuracy: 0.9269 - val_loss: 0.1806 - val_accuracy: 0.9515
# Epoch 37/50
# 496/496 [==============================] - 30s 61ms/step - loss: 0.2651 - accuracy: 0.9284 - val_loss: 0.1775 - val_accuracy: 0.9513
# Epoch 38/50
# 496/496 [==============================] - 31s 62ms/step - loss: 0.2606 - accuracy: 0.9293 - val_loss: 0.1830 - val_accuracy: 0.9481
# Epoch 39/50
# 496/496 [==============================] - 31s 62ms/step - loss: 0.2623 - accuracy: 0.9280 - val_loss: 0.1901 - val_accuracy: 0.9481
# Epoch 40/50
# 496/496 [==============================] - 29s 59ms/step - loss: 0.2614 - accuracy: 0.9287 - val_loss: 0.1689 - val_accuracy: 0.9550
# Epoch 41/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.2593 - accuracy: 0.9299 - val_loss: 0.1685 - val_accuracy: 0.9536
# Epoch 42/50
# 496/496 [==============================] - 30s 60ms/step - loss: 0.2521 - accuracy: 0.9316 - val_loss: 0.1852 - val_accuracy: 0.9499
# Epoch 43/50
# 496/496 [==============================] - 29s 59ms/step - loss: 0.2530 - accuracy: 0.9315 - val_loss: 0.1703 - val_accuracy: 0.9522
# Epoch 44/50
# 496/496 [==============================] - 29s 59ms/step - loss: 0.2520 - accuracy: 0.9332 - val_loss: 0.1662 - val_accuracy: 0.9532
# Epoch 45/50
# 496/496 [==============================] - 29s 59ms/step - loss: 0.2470 - accuracy: 0.9326 - val_loss: 0.1665 - val_accuracy: 0.9551
# Epoch 46/50
# 496/496 [==============================] - 30s 61ms/step - loss: 0.2443 - accuracy: 0.9340 - val_loss: 0.1715 - val_accuracy: 0.9537
# Epoch 47/50
# 496/496 [==============================] - 31s 63ms/step - loss: 0.2459 - accuracy: 0.9341 - val_loss: 0.1589 - val_accuracy: 0.9566
# Epoch 48/50
# 496/496 [==============================] - 31s 63ms/step - loss: 0.2414 - accuracy: 0.9352 - val_loss: 0.1772 - val_accuracy: 0.9522
# Epoch 49/50
# 496/496 [==============================] - 31s 63ms/step - loss: 0.2411 - accuracy: 0.9353 - val_loss: 0.1614 - val_accuracy: 0.9562
# Epoch 50/50
# 496/496 [==============================] - 32s 64ms/step - loss: 0.2405 - accuracy: 0.9357 - val_loss: 0.1619 - val_accuracy: 0.9547
# Saving to file
# Model stored in ./
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 10, 10, 256)       295168
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               524416
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                650
# =================================================================
# Total params: 1,659,594
# Trainable params: 1,659,210
# Non-trainable params: 384
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  0.240392  0.139649  0.158907      0.191792
# max  2.579538  0.935710  2.330192      0.956631
# Answer is 437 characters long

# %% [markdown]
# ## Part 3. Model interpretation (10 points)
# ### Question 3.1: Interpreting misclassifications (2 points)
# Study which errors are still made by your last model (model_2_2) by evaluating it on the test data. You do not need to retrain the model.
# * What is the accuracy of model_2_2 on the test data? Store this in 'test_accuracy_3_1'.
# * Plot the confusion matrix in 'plot_confusion_matrix' and discuss which classes are often confused.
# * Visualize the misclassifications in more depth by focusing on a single
# class (e.g. the number '2') and analyse which kinds of mistakes are made for that class. For instance, are the errors related to the background, noisiness, etc.? Implement the visualization in 'plot_misclassifications'.
# * Summarize your findings in 'answer_q_3_1'

# %%
from sklearn.metrics import confusion_matrix
import math
model = load_model_from_file(base_dir, "model_2_2" )
#acc = model.evaluate(rgb2gray(X_test), y_test)
#print(acc)

y_pred = model.predict(rgb2gray(X_test))
misclassified_samples = np.nonzero(np.argmax(y_test, axis=1) != np.argmax(y_pred, axis=1))[0]
#print(misclassified_samples)

test_accuracy_3_1 = 0.954
def plot_confusion_matrix():
  cm = confusion_matrix(np.argmax(y_test, axis=1),np.argmax(y_pred, axis=1))
  fig, ax = plt.subplots()
  im = ax.imshow(cm)
  ax.set_xticks(np.arange(11)), ax.set_yticks(np.arange(10))
  ax.set_xticklabels(np.arange(1,11))
  ax.set_yticklabels(np.arange(1,11))
  ax.set_ylabel('True')
  ax.set_xlabel('Predicted')
  for i in range(100):
      ax.text(int(i/10),i%10,cm[i%10,int(i/10)], ha="center", va="center", color="w")
def plot_misclassifications():
  fig, axes = plt.subplots(5, 5, figsize=(10,5))
  fig.tight_layout()
  n=0
  for nr, i in enumerate(misclassified_samples[:]):
    if np.argmax(y_test[i])+1 == 7:
      axes[math.floor(n/5),n%5].imshow(X_test[i])
      axes[math.floor(n/5),n%5].set_xlabel("Predicted: %s,\n Actual : %s" % ((np.argmax(y_pred[i])+1)%10,(np.argmax(y_test[i])+1)%10))
      axes[math.floor(n/5),n%5].set_xticks(()), axes[math.floor(n/5),n%5].set_yticks(())
      n+=1
      if n==25:
        break
  plt.show()

  
plot_confusion_matrix()
plot_misclassifications()

answer_q_3_1 = """
               As we can see in the confusion matrix, class 7 is often misclassified. So I plot 25 misclassified samples that have a actual label of 7 to see what kind of mistake are made. The main reason for misclassification is that some figures are too close in shape, like 1 and 7, even human makes this mistake. Also, there are other types of mistakes such as two or more figures appears together and the classifier is attracted by the other figure. 
               """
print("Answer is {} characters long".format(len(answer_q_3_1)))
# Out:
# 19858/19858 [==============================] - 7s 357us/sample - loss: 0.1683 - accuracy: 0.9540
# [0.16830583152451542, 0.95397323]
# Answer is 472 characters long

# %% [markdown]
# ### Question 3.2: Visualizing activations (4 points)
# * Implement a function `plot_activations()` that returns the most interesting activations (feature maps). Select the first example from the test set. Retrieve and visualize the activations of model 2_2 for that example (make sure you load that model in the function), for every filter for different convolutional layers (at different depths in the network).
# * Give an explanation (as detailed as you can) about your observations in 'answer_q_3_2'. Is your model indeed learning something useful?

# %%
from tensorflow.keras import models

model = load_model_from_file(base_dir, "model_2_2" )
img_tensor = rgb2gray(X_test)[0]
img_tensor = np.expand_dims(img_tensor, axis=0) 
layer_outputs = [layer.output for layer in model.layers[:18]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)
#print(activations)
images_per_row = 16
layer_names = []
for layer in model.layers[:18]:
    layer_names.append(layer.name)


def plot_activations():
    for i in [0,1,3,4,7,8]:
        start = i
        end = i+1
        for layer_name, layer_activation in zip(layer_names[start:end], activations[start:end]):
            n_features = layer_activation.shape[-1]
            size = layer_activation.shape[1]
            n_cols = n_features // images_per_row
            display_grid = np.zeros((size * n_cols, images_per_row * size))
            for col in range(n_cols):
                for row in range(images_per_row):
                    channel_image = layer_activation[0,
                                                    :, :,
                                                    col * images_per_row + row]
                    channel_image -= channel_image.mean()
                    channel_image /= channel_image.std()
                    channel_image *= 64
                    channel_image += 128
                    channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                    display_grid[col * size : (col + 1) * size,
                                row * size : (row + 1) * size] = channel_image
            scale = 1. / size
            plt.figure(figsize=(scale * display_grid.shape[1],
                                scale * display_grid.shape[0]))
            plt.title("Activation of layer {} ({})".format(i+1,layer_name))
            plt.grid(False)
            plt.imshow(display_grid, aspect='auto', cmap='viridis')

plt.show()
plot_activations()
answer_q_3_2 = """
               The activations of first layer keep the shape of original digits. There are about a half activations are left blank, this means no features are caputered by these filters.
               The activations become more abstract as we go deeper into the layers. This is because higher level layers begin to capture higher level features by combining lower level features. As we can see in the last several layers, the activations are mainly basic geometric elements such as curves, dots and lines.


               """
print("Answer is {} characters long".format(len(answer_q_3_2)))
# Out:
# Answer is 526 characters long

# %% [markdown]
# ### Question 3.3: Visualizing activations (4 points)
# * Again, select the first example from the test set, and the trained model_2_2.
# * Implement a function `plot_activation_map()` that builds and shows a class activation map for your last convolutional layer that highlights what the model is paying attention to when classifying the example.
# * If possible, superimpossible the activation map over the image. If not, plot
# them side by side. Implement a function 'plot_3_3' that returns the entire plot.

# %%
import cv2
from keras import backend as K
import seaborn as sns
import matplotlib.image as mpimg
from PIL import Image
img_path = 'D:\\clone\\assignment-3-Fakak\\8.jpg'
superimposed = 'D:\\clone\\assignment-3-Fakak\\CAM.jpeg'
model = load_model_from_file(base_dir,"model_2_2")



def plot_3_3():
    #fig, axes = plt.subplots(1, 1,  figsize=(10, 5))
    img=Image.open(superimposed)
    npimg=np.array(img)
    plt.imshow(npimg)
    plt.show()
    plt.cla()


def plot_activation_map():
    #fig, axes = plt.subplots(1, 1,  figsize=(10, 5))
    x = rgb2gray(X_test)[0]
    x = np.expand_dims(x,axis=0)
    pred = model.predict(x)
    class_idx = np.argmax(pred[0])
    class_output = model.output[:,class_idx]
    last_conv_layer = model.layers[8]
    grads = K.gradients(class_output,last_conv_layer.output)[0]
    pooled_grads = K.mean(grads,axis=(0,1,2))
    iterate = K.function([model.input],[pooled_grads,last_conv_layer.output[0]])
    pooled_grads_value, conv_layer_output_value = iterate([x])
    for i in range(256):
        conv_layer_output_value[:,:,i] *= pooled_grads_value[i]           
    heatmap = np.mean(conv_layer_output_value, axis=-1)
    heatmap = np.maximum(heatmap,0)
    heatmap /= np.max(heatmap)
    plt.imshow(heatmap)
    plt.show()
    plt.cla() 
    img = cv2.imread(img_path)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    hif = 0.8
    superimposed_img = heatmap * hif + img    
    cv2.imwrite(superimposed, superimposed_img)

plot_3_3()
plot_activation_map()

# %% [markdown]
# ## Part 4. Transfer learning (10 points)
# ### Question 4.1 Fast feature extraction with VGG16 (5 points)
# - Import the VGG16 model, pretrained on ImageNet. [See here](https://keras.io/applications/). Only import the convolutional part, not the dense layers.
# - Implement a function 'build_model_4_1` that adds a dense layer to the convolutional base, and freezes the convolutional base. Consider unfreezing the last few convolutional layers and evaluate whether that works better.
# - Train the resulting model on the *original* (colored) training data
# - Evaluate the resulting model using 'run_evaluate'. Discuss the observed performance in 'answer_q_4_1'.

# %%
from tensorflow.keras.applications.vgg16 import VGG16
con_layer_index = [1, 2, 4, 5, 7, 8, 9, 11, 12, 13, 15, 16, 17]

def build_model_4_1():
    model = models.Sequential()
    model.add(VGG16(include_top = False, weights = 'imagenet', input_shape=(32, 32, 3), pooling='max'))
    #model.summary()
    
    for i in con_layer_index[2:13]:    
        layer = model.layers[0].layers[i]
        layer.trainable = False
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='rmsprop' ,loss='categorical_crossentropy',metrics=['accuracy'])
    return model
run_evaluation("model_4_1", build_model_4_1, evaluation_split, base_dir, 
               train=True, epochs=50, batch_size=128)

answer_q_4_1 = """
               The accuracy is approximately 65% if all convolution layers are freezed in vgg16. If we enable two convolutional layers(which is block 1),
               we get an accuracy 84.3%. Obviously, unfreeze convolutional layers makes performance better.
               """
print("Answer is {} characters long".format(len(answer_q_4_1)))
# Out:
# Training the model
# Train on 63544 samples, validate on 15887 samples
# Epoch 1/50
# 63544/63544 [==============================] - 23s 366us/sample - loss: 1.5180 - accuracy: 0.4846 - val_loss: 1.2642 - val_accuracy: 0.5803
# Epoch 2/50
# 63544/63544 [==============================] - 19s 297us/sample - loss: 1.1509 - accuracy: 0.6146 - val_loss: 1.0823 - val_accuracy: 0.6335
# Epoch 3/50
# 63544/63544 [==============================] - 20s 310us/sample - loss: 1.0005 - accuracy: 0.6687 - val_loss: 0.9747 - val_accuracy: 0.6738
# Epoch 4/50
# 63544/63544 [==============================] - 21s 325us/sample - loss: 0.9085 - accuracy: 0.6990 - val_loss: 0.9334 - val_accuracy: 0.6899
# Epoch 5/50
# 63544/63544 [==============================] - 21s 332us/sample - loss: 0.8402 - accuracy: 0.7246 - val_loss: 0.8427 - val_accuracy: 0.7207
# Epoch 6/50
# 63544/63544 [==============================] - 21s 335us/sample - loss: 0.7902 - accuracy: 0.7404 - val_loss: 0.8709 - val_accuracy: 0.7130
# Epoch 7/50
# 63544/63544 [==============================] - 22s 343us/sample - loss: 0.7527 - accuracy: 0.7534 - val_loss: 0.7638 - val_accuracy: 0.7485
# Epoch 8/50
# 63544/63544 [==============================] - 22s 347us/sample - loss: 0.7181 - accuracy: 0.7649 - val_loss: 0.7582 - val_accuracy: 0.7484
# Epoch 9/50
# 63544/63544 [==============================] - 22s 349us/sample - loss: 0.6921 - accuracy: 0.7732 - val_loss: 0.7315 - val_accuracy: 0.7593
# Epoch 10/50
# 63544/63544 [==============================] - 22s 348us/sample - loss: 0.6667 - accuracy: 0.7819 - val_loss: 0.6860 - val_accuracy: 0.7759
# Epoch 11/50
# 63544/63544 [==============================] - 22s 349us/sample - loss: 0.6500 - accuracy: 0.7893 - val_loss: 0.6626 - val_accuracy: 0.7867
# Epoch 12/50
# 63544/63544 [==============================] - 22s 349us/sample - loss: 0.6326 - accuracy: 0.7948 - val_loss: 0.7053 - val_accuracy: 0.7675
# Epoch 13/50
# 63544/63544 [==============================] - 23s 365us/sample - loss: 0.6180 - accuracy: 0.7996 - val_loss: 0.7133 - val_accuracy: 0.7594
# Epoch 14/50
# 63544/63544 [==============================] - 23s 359us/sample - loss: 0.6065 - accuracy: 0.8036 - val_loss: 0.6880 - val_accuracy: 0.7739
# Epoch 15/50
# 63544/63544 [==============================] - 23s 368us/sample - loss: 0.5918 - accuracy: 0.8084 - val_loss: 0.6430 - val_accuracy: 0.7913
# Epoch 16/50
# 63544/63544 [==============================] - 24s 373us/sample - loss: 0.5825 - accuracy: 0.8117 - val_loss: 0.6597 - val_accuracy: 0.7838
# Epoch 17/50
# 63544/63544 [==============================] - 24s 372us/sample - loss: 0.5720 - accuracy: 0.8148 - val_loss: 0.6423 - val_accuracy: 0.7915
# Epoch 18/50
# 63544/63544 [==============================] - 23s 367us/sample - loss: 0.5624 - accuracy: 0.8183 - val_loss: 0.6101 - val_accuracy: 0.8028
# Epoch 19/50
# 63544/63544 [==============================] - 23s 366us/sample - loss: 0.5524 - accuracy: 0.8209 - val_loss: 0.5834 - val_accuracy: 0.8127
# Epoch 20/50
# 63544/63544 [==============================] - 23s 368us/sample - loss: 0.5443 - accuracy: 0.8246 - val_loss: 0.6073 - val_accuracy: 0.8044
# Epoch 21/50
# 63544/63544 [==============================] - 24s 376us/sample - loss: 0.5351 - accuracy: 0.8266 - val_loss: 0.5917 - val_accuracy: 0.8113
# Epoch 22/50
# 63544/63544 [==============================] - 24s 374us/sample - loss: 0.5262 - accuracy: 0.8315 - val_loss: 0.5553 - val_accuracy: 0.8223
# Epoch 23/50
# 63544/63544 [==============================] - 24s 373us/sample - loss: 0.5207 - accuracy: 0.8318 - val_loss: 0.5938 - val_accuracy: 0.8105
# Epoch 24/50
# 63544/63544 [==============================] - 23s 366us/sample - loss: 0.5120 - accuracy: 0.8349 - val_loss: 0.5684 - val_accuracy: 0.8210
# Epoch 25/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.5057 - accuracy: 0.8371 - val_loss: 0.5668 - val_accuracy: 0.8163
# Epoch 26/50
# 63544/63544 [==============================] - 24s 380us/sample - loss: 0.4975 - accuracy: 0.8409 - val_loss: 0.5679 - val_accuracy: 0.8183
# Epoch 27/50
# 63544/63544 [==============================] - 24s 381us/sample - loss: 0.4921 - accuracy: 0.8435 - val_loss: 0.5627 - val_accuracy: 0.8224
# Epoch 28/50
# 63544/63544 [==============================] - 24s 379us/sample - loss: 0.4869 - accuracy: 0.8439 - val_loss: 0.6107 - val_accuracy: 0.8001
# Epoch 29/50
# 63544/63544 [==============================] - 24s 382us/sample - loss: 0.4803 - accuracy: 0.8455 - val_loss: 0.6134 - val_accuracy: 0.8034
# Epoch 30/50
# 63544/63544 [==============================] - 24s 381us/sample - loss: 0.4756 - accuracy: 0.8466 - val_loss: 0.5616 - val_accuracy: 0.8212
# Epoch 31/50
# 63544/63544 [==============================] - 24s 380us/sample - loss: 0.4703 - accuracy: 0.8494 - val_loss: 0.5316 - val_accuracy: 0.8307
# Epoch 32/50
# 63544/63544 [==============================] - 24s 379us/sample - loss: 0.4651 - accuracy: 0.8502 - val_loss: 0.5240 - val_accuracy: 0.8334
# Epoch 33/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.4605 - accuracy: 0.8526 - val_loss: 0.5494 - val_accuracy: 0.8265
# Epoch 34/50
# 63544/63544 [==============================] - 24s 379us/sample - loss: 0.4549 - accuracy: 0.8551 - val_loss: 0.5510 - val_accuracy: 0.8242
# Epoch 35/50
# 63544/63544 [==============================] - 24s 379us/sample - loss: 0.4528 - accuracy: 0.8546 - val_loss: 0.5308 - val_accuracy: 0.8304
# Epoch 36/50
# 63544/63544 [==============================] - 24s 379us/sample - loss: 0.4484 - accuracy: 0.8566 - val_loss: 0.5173 - val_accuracy: 0.8359
# Epoch 37/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.4415 - accuracy: 0.8587 - val_loss: 0.5692 - val_accuracy: 0.8199
# Epoch 38/50
# 63544/63544 [==============================] - 24s 379us/sample - loss: 0.4386 - accuracy: 0.8596 - val_loss: 0.5575 - val_accuracy: 0.8246
# Epoch 39/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.4345 - accuracy: 0.8618 - val_loss: 0.5402 - val_accuracy: 0.8272
# Epoch 40/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.4318 - accuracy: 0.8615 - val_loss: 0.5368 - val_accuracy: 0.8294
# Epoch 41/50
# 63544/63544 [==============================] - 24s 377us/sample - loss: 0.4284 - accuracy: 0.8630 - val_loss: 0.5307 - val_accuracy: 0.8384
# Epoch 42/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.4231 - accuracy: 0.8647 - val_loss: 0.4984 - val_accuracy: 0.8431
# Epoch 43/50
# 63544/63544 [==============================] - 24s 378us/sample - loss: 0.4211 - accuracy: 0.8649 - val_loss: 0.5123 - val_accuracy: 0.8338
# Epoch 44/50
# 63544/63544 [==============================] - 24s 380us/sample - loss: 0.4183 - accuracy: 0.8669 - val_loss: 0.5622 - val_accuracy: 0.8243
# Epoch 45/50
# 63544/63544 [==============================] - 24s 381us/sample - loss: 0.4130 - accuracy: 0.8679 - val_loss: 0.5628 - val_accuracy: 0.8295
# Epoch 46/50
# 63544/63544 [==============================] - 24s 380us/sample - loss: 0.4106 - accuracy: 0.8689 - val_loss: 0.5153 - val_accuracy: 0.8381
# Epoch 47/50
# 63544/63544 [==============================] - 24s 380us/sample - loss: 0.4076 - accuracy: 0.8691 - val_loss: 0.5215 - val_accuracy: 0.8379
# Epoch 48/50
# 63544/63544 [==============================] - 24s 384us/sample - loss: 0.4037 - accuracy: 0.8712 - val_loss: 0.5223 - val_accuracy: 0.8369
# Epoch 49/50
# 63544/63544 [==============================] - 24s 381us/sample - loss: 0.4021 - accuracy: 0.8715 - val_loss: 0.5638 - val_accuracy: 0.8226
# Epoch 50/50
# 63544/63544 [==============================] - 24s 381us/sample - loss: 0.3997 - accuracy: 0.8723 - val_loss: 0.5000 - val_accuracy: 0.8417
# Saving to file
# Model stored in ./
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 512)               14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 14,748,170
# Trainable params: 72,202
# Non-trainable params: 14,675,968
# _________________________________________________________________
# None
#          loss  accuracy  val_loss  val_accuracy
# min  0.399657  0.484609  0.498355      0.580286
# max  1.517995  0.872340  1.264217      0.843079
# Answer is 278 characters long

# %% [markdown]
# ### Question 4.2 Embeddings and pipelines (5 points)
# - Generate embeddings of the original images by running them through the trained convolutional part of model_4_1 (without the dense layer) and returning the output. Embed the training and test data and store them to disk using the helper functions below. Implement a function `store_embeddings` that loads model_4_1 and stores all necessary embeddings to file. Make sure to run it once so that the embeddings are stored (and submitted).
# - Implement a function 'generate_pipeline' that returns an scikit-learn pipeline. You can use any non-deep learning technique (eg. SVMs, RFs,...), and preprocessing technique. You can do model selection using the validation set.
# - Implement a function 'evaluate_pipeline' that evaluates a given pipeline on a given training and test set.
# - Implement a function 'evaluation_4_2' that evaluates your pipeline on the embedded training and test set (loaded from file) and returns the accuracy.
# - Describe what you did and what you observed. Report the obtained accuracy score. Can you beat your best model thus far?

# %%
import pickle
import gzip

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer, PowerTransformer, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier

model = load_model_from_file(base_dir, "model_4_1")
#model.summary()
def store_embedding(X, name):  
  with gzip.open(os.path.join(base_dir, name+'_embedding.p'), 'wb') as file_pi:
    pickle.dump(X, file_pi)

def load_embedding(name):
  with gzip.open(os.path.join(base_dir, name+'_embedding.p'), 'rb') as file_pi:
    return pickle.load(file_pi)

def store_embeddings():
  """ Stores all necessary embeddings to file
  """
  vgg16_conv_layers = model.get_layer('vgg16')
  train = vgg16_conv_layers.predict(X_train_all)
  train = train.reshape(train.shape[0], 512)
  test = vgg16_conv_layers.predict(X_test)
  test = test.reshape(test.shape[0], 512)
  store_embedding(train, 'vgg16_train_all')
  store_embedding(test, 'vgg16_test')

def generate_pipeline():
  """ Returns an sklearn pipeline.
  """
#   clf = DecisionTreeClassifier(random_state=1)
#   return Pipeline(steps=[('classifier', clf)])
#   clf = svm.SVC(kernel = 'rbf', random_state=1)
  #clf = LogisticRegression(random_state=1)
  clf = RandomForestClassifier(random_state=1)
  return Pipeline(steps=[('classifier', clf)])


def evaluate_pipeline(pipeline, X_train_embeded, y_train, X_test_embeded, y_test):
  """ Evaluates the given pipeline, trained on the given embedded training set and 
      evaluated on the supplied embedded test set. Returns the accuracy score.
  """
  #X_train_reshape = np.reshape(X_train,(np.shape(X_train)[0],np.shape(X_train)[1]*np.shape(X_train)[2]*np.shape(X_train)[3]))
  #X_test_reshape = np.reshape(X_test,(np.shape(X_test)[0],np.shape(X_test)[1]*np.shape(X_test)[2]*np.shape(X_test)[3]))
  X_train_embeded = X_train_embeded.reshape(X_train_embeded.shape[0], -1)
  X_test_embeded = X_test_embeded.reshape(X_test_embeded.shape[0], -1)
  pipeline.fit(X_train_embeded, y_train)
  return pipeline.score(X_test_embeded, y_test)

def evaluation_4_2(X_train_embeded, y_train, X_test_embeded, y_test):
  """ Runs 'evaluate_pipeline' with embedded versions of the input data 
  and returns the accuracy.
  """
  pipeline = generate_pipeline()
  score = evaluate_pipeline(pipeline, X_train_embeded, y_train.argmax(axis=1), X_test_embeded, y_test.argmax(axis=1))
  return score

store_embeddings()
embeded_train = load_embedding('vgg16_train_all')
embeded_test = load_embedding('vgg16_test')
score = evaluation_4_2(embeded_train, y_train_all, embeded_test, y_test)
#score = 0.533
#print("score:",score)


answer_q_4_2 = """
              I use randomforestrwithout scaler. The score is 0.70, which is far from the best model. That's may be because in 4.1, I only unfreeze 2 convolutional layers. If more(or all) con layers are unfreezed, the performance would be better. But it takes a lot of time to retrain the model, so I skip it. 
               """
print("Pipeline:",generate_pipeline())
print("Answer is {} characters long".format(len(answer_q_4_2)))
# Out:
# (79431, 512)
# (19858, 512)
# score: 0.5334374055796153
# Pipeline: Pipeline(memory=None,
#          steps=[('classifier',
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=1,
#                                         verbose=0, warm_start=False))],
#          verbose=False)
# Answer is 327 characters long
